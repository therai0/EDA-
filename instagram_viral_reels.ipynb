# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Loading dataset and basic overview

# %%
df = pd.read_csv("./data/instagram data.csv")
df.head()
# Out:
#                                 reel_id                            creator_id  \
# 0  c437715e-d1e4-4f40-8548-8718243c6516  70c2ca5a-9d3a-4ba0-9aed-62cdbbc1663f
# 1  9097bb11-0e03-4360-a239-6613ed2025df  b6bb4240-6341-47ce-bdd4-86fcba18d9ad
# 2  a8e09994-3314-400b-9f3a-683b494f1070  7902b14d-cb95-4673-8ef1-482ff5151801
# 3  afafb1c3-90c4-4918-8910-3a2338a812c5  3878d999-6087-4a40-a59e-45abe8978736
# 4  dcb1e68c-79ba-4808-bf74-d102fa68a526  4077faf8-bc0c-42df-b060-f90d074e8e01
#
#    creator_followers  posting_time  reel_length_sec  hook_strength_score  \
# 0            4208388             3               31             0.451657
# 1            4096880             4               38             0.988437
# 2            2624351             0               13             0.019949
# 3             437778            23               15             0.564485
# 4            4388903             3               30             0.556782
#
# ...

# %%
df.tail()
# Out:
#                                     reel_id  \
# 99995  1955a53c-eab3-4393-b861-dd2794b104c6
# 99996  9eab5220-f357-4644-bed7-19139c9dea50
# 99997  02e1f63b-deb5-4f1d-bcee-7c8fb1669b17
# 99998  f33b38e6-ec18-4651-b897-1ce978950acc
# 99999  b0319b22-e0e2-45bc-bb8c-457964d6c9c9
#
#                                  creator_id  creator_followers  posting_time  \
# 99995  4c664f20-bdde-4af2-b36a-31c7b9da70d0            3946383            18
# 99996  58d5c005-7989-4e85-9c9f-506b3e2e8f6d            4314894            22
# 99997  264fb15b-9799-4b3e-9576-6130a09e9923            1198854            10
# 99998  2dd83dc1-bf4d-4759-8b5d-beba82344866            3965012             4
# 99999  5dd4deb4-bc7d-4411-be3a-45d13730ebc2             436933            23
#
#        reel_length_sec  hook_strength_score  caption_length  hashtags_count  \
# 99995               51             0.351408             298               9
# 99996               39             0.094755              83              16
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   reel_id                   100000 non-null  str
#  1   creator_id                100000 non-null  str
#  2   creator_followers         100000 non-null  int64
#  3   posting_time              100000 non-null  int64
#  4   reel_length_sec           100000 non-null  int64
#  5   hook_strength_score       100000 non-null  float64
#  6   caption_length            100000 non-null  int64
#  7   hashtags_count            100000 non-null  int64
#  8   trending_audio            100000 non-null  bool
#  9   audio_popularity_score    100000 non-null  float64
#  10  video_quality_score       100000 non-null  float64
#  11  editing_quality_score     100000 non-null  float64
#  12  avg_watch_time_sec        100000 non-null  float64
# ...

# %%
df.shape
# Out:
# (100000, 26)

# %%
df.columns
# Out:
# Index(['reel_id', 'creator_id', 'creator_followers', 'posting_time',
#        'reel_length_sec', 'hook_strength_score', 'caption_length',
#        'hashtags_count', 'trending_audio', 'audio_popularity_score',
#        'video_quality_score', 'editing_quality_score', 'avg_watch_time_sec',
#        'retention_rate', 'completion_rate', 'rewatch_rate', 'likes',
#        'comments', 'shares', 'saves', 'engagement_rate', 'impressions',
#        'reach', 'non_follower_reach_ratio', 'explore_page_boost',
#        'virality_score'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# reel_id                     0
# creator_id                  0
# creator_followers           0
# posting_time                0
# reel_length_sec             0
# hook_strength_score         0
# caption_length              0
# hashtags_count              0
# trending_audio              0
# audio_popularity_score      0
# video_quality_score         0
# editing_quality_score       0
# avg_watch_time_sec          0
# retention_rate              0
# completion_rate             0
# rewatch_rate                0
# likes                       0
# comments                    0
# shares                      0
# saves                       0
# engagement_rate             0
# impressions                 0
# reach                       0
# non_follower_reach_ratio    0
# explore_page_boost          0
# virality_score              0
# dtype: int64

# %% [markdown]
# ## Univariant Analysis of Numeric columns

# %% [markdown]
# ## Creator followers
#  Normally distributed data

# %%
df["creator_followers"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["creator_followers"].describe()
# Out:
# count    100000.00
# mean    2501073.82
# std     1446318.36
# min         521.00
# 25%     1241769.75
# 50%     2500456.00
# 75%     3754132.50
# max     4999946.00
# Name: creator_followers, dtype: float64

# %%
plt.title("Histogram of Create followers")
plt.hist(df["creator_followers"])

plt.xlabel("Number of follower(0-500000)")
plt.ylabel("Number of creator")
plt.show()

# %%
df["creator_followers"].skew()
# Out:
# np.float64(0.0013472461247607324)

# %% [markdown]
# ## Posting Time

# %%
df["posting_time"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["posting_time"].describe()
# Out:
# count   100000.00
# mean        11.50
# std          6.92
# min          0.00
# 25%          6.00
# 50%         11.00
# 75%         18.00
# max         23.00
# Name: posting_time, dtype: float64

# %%
plt.hist(df["posting_time"])
plt.title("Histogram of Posting time")
plt.xlabel("Time")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ##  Reel Lenght Second

# %%
df["reel_length_sec"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["reel_length_sec"].describe()
# Out:
# count   100000.00
# mean        32.50
# std         16.15
# min          5.00
# 25%         19.00
# 50%         33.00
# 75%         46.00
# max         60.00
# Name: reel_length_sec, dtype: float64

# %%
plt.title("Histogram of Reel Duration")
plt.hist(df["reel_length_sec"])
plt.xlabel("Duration of reel(second)")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Hook Strength Score

# %%
df["hook_strength_score"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["hook_strength_score"].describe()
# Out:
# count   100000.00
# mean         0.50
# std          0.29
# min          0.00
# 25%          0.25
# 50%          0.50
# 75%          0.75
# max          1.00
# Name: hook_strength_score, dtype: float64

# %% [markdown]
# ##

# %%
plt.title("Histogram of Hook Strength score")
plt.hist(df["hook_strength_score"])
plt.xlabel("Reel Score")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Caption Lenght

# %%
df["caption_length"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["caption_length"].describe()
# Out:
# count   100000.00
# mean       149.88
# std         86.86
# min          0.00
# 25%         75.00
# 50%        150.00
# 75%        225.00
# max        300.00
# Name: caption_length, dtype: float64

# %%
plt.title("Histogram of Caption")
plt.hist(df["caption_length"])
plt.xlabel("Caption lenght")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Hastags count

# %%
df["hashtags_count"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["hashtags_count"].describe()
# Out:
# count   100000.00
# mean        15.07
# std          8.95
# min          0.00
# 25%          7.00
# 50%         15.00
# 75%         23.00
# max         30.00
# Name: hashtags_count, dtype: float64

# %%
plt.title("Histogram of Hastags counts")
plt.hist(df["hashtags_count"])
plt.xlabel("Number of Hastags")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Audio Popularity Score

# %%
df["audio_popularity_score"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["audio_popularity_score"].describe()
# Out:
# count   100000.00
# mean         0.50
# std          0.29
# min          0.00
# 25%          0.25
# 50%          0.50
# 75%          0.75
# max          1.00
# Name: audio_popularity_score, dtype: float64

# %%
plt.title("Histogram of Audio Popularity Score")
plt.hist(df["audio_popularity_score"])
plt.xlabel("Score")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Video Quality Score

# %%
df["video_quality_score"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["video_quality_score"].describe()
# Out:
# count   100000.00
# mean         0.50
# std          0.29
# min          0.00
# 25%          0.25
# 50%          0.50
# 75%          0.75
# max          1.00
# Name: video_quality_score, dtype: float64

# %%
plt.title("Histogram of Video Quality Score")
plt.hist(df["video_quality_score"])
plt.xlabel("Score")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Editing Quality Score

# %%
df["editing_quality_score"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["editing_quality_score"].describe()
# Out:
# count   100000.00
# mean         0.50
# std          0.29
# min          0.00
# 25%          0.25
# 50%          0.50
# 75%          0.75
# max          1.00
# Name: editing_quality_score, dtype: float64

# %%
plt.title("Histogram of Editing Quality Score")
plt.hist(df["editing_quality_score"])
plt.xlabel("Score")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Average Watch Time(sec)

# %%
df["avg_watch_time_sec"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["avg_watch_time_sec"].describe()
# Out:
# count   100000.00
# mean        30.04
# std         17.32
# min          0.00
# 25%         15.04
# 50%         30.04
# 75%         45.05
# max         60.00
# Name: avg_watch_time_sec, dtype: float64

# %%
plt.title("Histogram of Average Watch Time(in sec)")
plt.hist(df["avg_watch_time_sec"])
plt.xlabel("Time(in sec)")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Retention Rate

# %%
df["retention_rate"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["retention_rate"].describe()
# Out:
# count   100000.00
# mean         0.50
# std          0.29
# min          0.00
# 25%          0.25
# 50%          0.50
# 75%          0.75
# max          1.00
# Name: retention_rate, dtype: float64

# %%
plt.title("Histogram of Retention Rate")
plt.hist(df["retention_rate"])
plt.xlabel("Retention rate")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Completion Rate

# %%
df["completion_rate"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["completion_rate"].describe()
# Out:
# count   100000.00
# mean         0.50
# std          0.29
# min          0.00
# 25%          0.25
# 50%          0.50
# 75%          0.75
# max          1.00
# Name: completion_rate, dtype: float64

# %%
plt.title("Histogram of Completion Rate")
plt.hist(df["completion_rate"])
plt.xlabel("Completion rate")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Rewatch Rate

# %%
df["rewatch_rate"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["rewatch_rate"].describe()
# Out:
# count   100000.00
# mean         0.50
# std          0.29
# min          0.00
# 25%          0.25
# 50%          0.50
# 75%          0.75
# max          1.00
# Name: rewatch_rate, dtype: float64

# %%
plt.title("Histogram of Rewatch Rate")
plt.hist(df["rewatch_rate"])
plt.xlabel("Rewatch rate")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Likes in Reel

# %%
df["likes"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["likes"].describe()
# Out:
# count   100000.00
# mean    499380.48
# std     288671.82
# min         27.00
# 25%     247993.50
# 50%     499965.00
# 75%     748950.50
# max     999994.00
# Name: likes, dtype: float64

# %%
plt.title("Histogram of Likes")
plt.hist(df["likes"])
plt.xlabel("Number of likes")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Comments

# %%
df["comments"].describe()
# Out:
# count   100000.00
# mean     25028.94
# std      14446.58
# min          0.00
# 25%      12476.00
# 50%      25024.00
# 75%      37564.50
# max      50000.00
# Name: comments, dtype: float64

# %%
plt.title("Histogram of Comments")
plt.hist(df["comments"])
plt.xlabel("Number of Comments")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Shares

# %%
df["shares"].describe()
# Out:
# count   100000.00
# mean     14982.64
# std       8679.93
# min          0.00
# 25%       7485.00
# 50%      14969.00
# 75%      22517.25
# max      30000.00
# Name: shares, dtype: float64

# %%
plt.title("Histogram of Shares")
plt.hist(df["shares"])
plt.xlabel("Number of Shares")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Saves

# %%
df["saves"].describe()
# Out:
# count   100000.00
# mean     14996.00
# std       8649.76
# min          0.00
# 25%       7524.00
# 50%      14966.50
# 75%      22487.00
# max      30000.00
# Name: saves, dtype: float64

# %%
plt.title("Histogram of Saves")
plt.hist(df["saves"])
plt.xlabel("Number of Saves")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Engagement Rate

# %%
df["engagement_rate"].describe()
# Out:
# count   100000.00
# mean         0.50
# std          0.29
# min          0.00
# 25%          0.25
# 50%          0.50
# 75%          0.75
# max          1.00
# Name: engagement_rate, dtype: float64

# %%
plt.title("Histogram of Engagement Rate")
plt.hist(df["engagement_rate"])
plt.xlabel("Number of Engagement Rate")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Impression

# %%
df["impressions"].describe()
# Out:
# count     100000.00
# mean    49930314.96
# std     28827193.75
# min         2737.00
# 25%     24920348.25
# 50%     49917048.50
# 75%     74925291.75
# max     99999506.00
# Name: impressions, dtype: float64

# %%
plt.title("Histogram of  Impression")
plt.hist(df["impressions"])
plt.xlabel("Number of  Impression")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Reach of Reels

# %%
df["reach"].describe()
# Out:
# count     100000.00
# mean    49969879.99
# std     28884795.71
# min         1838.00
# 25%     24939379.50
# 50%     49975508.00
# 75%     74994499.50
# max     99997016.00
# Name: reach, dtype: float64

# %%
plt.title("Histogram of Reach")
plt.hist(df["reach"])
plt.xlabel("Number of Reach")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Non Follower Reach Ratio

# %%
df["non_follower_reach_ratio"].describe()
# Out:
# count   100000.00
# mean         0.50
# std          0.29
# min          0.00
# 25%          0.25
# 50%          0.50
# 75%          0.75
# max          1.00
# Name: non_follower_reach_ratio, dtype: float64

# %%
plt.title("Histogram of Non follower Reach ratio")
plt.hist(df["non_follower_reach_ratio"])
plt.xlabel("Non follower reach ratio")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Virality Score

# %%
df["virality_score"].describe()
# Out:
# count    100000.000000
# mean         50.120510
# std          28.948261
# min           0.000075
# 25%          25.101121
# 50%          50.089255
# 75%          75.280233
# max          99.999949
# Name: virality_score, dtype: float64

# %%
plt.title("Histogram of Virality Score")
plt.hist(df["virality_score"])
plt.xlabel("Virality score")
plt.ylabel("Number of creator")
plt.show()

# %% [markdown]
# ## Univariant Analysis of Categorical Columns

# %% [markdown]
# ## Trending Audio

# %%
count = df["trending_audio"].value_counts()
# Out:
# <bound method Series.count of trending_audio
# False    50083
# True     49917
# Name: count, dtype: int64>

# %%
plt.pie([50083,49917],labels=["False","True"],autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x12a0b6bd0>,
# ...
#  [Text(-0.0028682561016447955, 1.0999962604967963, 'False'),
#   Text(0.0028680900068304045, -1.0999962609298783, 'True')],
#  [Text(-0.0015645033281698883, 0.5999979602709797, '50.1%'),
#   Text(0.0015644127309984025, -0.5999979605072062, '49.9%')])

# %%
df["trending_audio"].describe()
# Out:
# count     100000
# unique         2
# top        False
# freq       50083
# Name: trending_audio, dtype: object

# %% [markdown]
# ## Explore Page Boost

# %%
df["explore_page_boost"].value_counts()
# Out:
# explore_page_boost
# False    50318
# True     49682
# Name: count, dtype: int64

# %%
plt.pie([50318,49682],labels=["False","True"],autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x12a27a710>,
# ...
#  [Text(-0.010989233240680239, 1.0999451062452081, 'False'),
#   Text(0.010989591648288015, -1.099945102664403, 'True')],
#  [Text(-0.00599412722218922, 0.5999700579519316, '50.3%'),
#   Text(0.005994322717248007, -0.5999700559987652, '49.7%')])
